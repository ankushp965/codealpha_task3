# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

# %% [raw]
# df=pd.read_csv('C:\\Users\\USER\\PYTHON FILES\\main.py\\PYTHON_JPNB_MAIN\\PRACTICE\\Ice Cream Sales.csv',encoding='unicode_escape')

# %%
df.head(10)
# Out:
#    Temperature  Ice Cream Profits
# 0           39              13.17
# 1           40              11.88
# 2           41              18.82
# 3           42              18.65
# 4           43              17.02
# 5           43              15.88
# 6           44              19.07
# 7           44              19.57
# 8           45              21.62
# 9           45              22.34

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 365 entries, 0 to 364
# Data columns (total 2 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Temperature        365 non-null    int64
#  1   Ice Cream Profits  365 non-null    float64
# dtypes: float64(1), int64(1)
# memory usage: 5.8 KB

# %%
df.isnull().sum()
# Out:
# Temperature          0
# Ice Cream Profits    0
# dtype: int64

# %%
sns.scatterplot(x='Ice Cream Profits',y='Temperature',data=df)
plt.title('Temp vs Ice Cream Profits')
plt.xlabel('Ice Cream Profits(dollar)')
plt.ylabel('Temperature(F)')
# Out:
# Text(0, 0.5, 'Temperature(F)')

# %%
X= df[['Temperature']]
Y= df[['Ice Cream Profits']]

X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2)

model=LinearRegression()
model.fit(X_train,Y_train)

Y_pred=model.predict(X_test)

# %%
X_test.shape
# Out:
# (73, 1)

# %%
len(Y_pred)
# Out:
# 73

# %%
plt.scatter(Y_train,X_train) 
Y_pred=model.predict(X_test)

plt.scatter(Y_pred,X_test,color='red')
plt.title('Temp vs Ice Cream Profits')
plt.xlabel('Ice Cream Profits(dollar)')
plt.ylabel('Temperature(F)')
# Out:
# Text(0, 0.5, 'Temperature(F)')

# %%
print('r2_score:',r2_score(Y_test,Y_pred)*100)
print('Mean_Squared_Error:',mean_squared_error(Y_test,Y_pred))
print('Mean_Absolute_Error:',mean_absolute_error(Y_test,Y_pred))
# Out:
# r2_score: 97.46765125775634
# Mean_Squared_Error: 6.472481142271695
# Mean_Absolute_Error: 1.9199209688223309
